# %%
import pandas as pd  
import numpy as np  
from datetime import date, datetime, timedelta 
from pathlib import Path
import re
import ast
import datetime

# %%
HOME = Path.cwd()
PATH_TO_PARENT = HOME.parent.parent
PATH_TO_DATA_FOLDER = PATH_TO_PARENT / "data" / "curated"

PATH_OPENTABLE_RES_DATA = PATH_TO_DATA_FOLDER / "yelp_review_data_Portland_ME_2024-06-29.csv_CURATED.csv"

# %%
df = pd.read_csv(PATH_OPENTABLE_RES_DATA, index_col = False)

# %%
df.head(50)
# Out:
#     Unnamed: 0     restaurant_name    datelike   reviewer_name  \
# 0            0  thistle and grouse  2024-06-20       Briana T.
# 1            1  thistle and grouse  2024-06-07    Elisabeth M.
# 2            2  thistle and grouse  2024-06-07        Jessi C.
# 3            3  thistle and grouse  2024-06-07          Ann T.
# 4            4  thistle and grouse  2024-06-01         Bill D.
# 5            5  thistle and grouse  2024-05-29         Ryan C.
# 6            6  thistle and grouse  2024-05-12         Ivan G.
# 7            7  thistle and grouse  2024-05-04      Michael O.
# 8            8  thistle and grouse  2024-04-24    Elizabeth C.
# 9            9  thistle and grouse  2024-04-21       Kerrie D.
# 10          10  thistle and grouse  2024-04-12          Keelin
# 11          11  thistle and grouse  2024-03-06        Laura J.
# 12          12  thistle and grouse  2024-03-04       Rachel S.
# 13          13  thistle and grouse  2024-03-02      Brendan R.
# ...

# %%
text = "5 star rating"
regex = r'(\d+)'

match = re.findall(regex, text)
rating_str = match[0]
rating = int(rating_str)
print(rating)
