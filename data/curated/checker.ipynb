# %%
import pandas as pd

# %%
open_table_review = pd.read_csv("open_table_review_data_Portland_ME_2024-07-21.csv_CURATED.csv")
open_table_res = pd.read_csv("open_table_restaurant_data_Portland_ME_2024-07-21.csv_CURATED.csv")
yelp_review = pd.read_csv("yelp_review_data_Portland_ME_2024-06-29.csv_CURATED.csv")
yelp_res = pd.read_csv("yelp_restaurant_data_Portland_ME_2024-06-29_CURATED.csv")

# %%
yelp_res[yelp_res["restaurant_name"] == "monte's fine foods"]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, restaurant_name, city, state, price_point, tags]
# Index: []

# %%
yelp_res["restaurant_name"].unique()
# Out:
# array(['thistle and grouse', 'street and co.', 'duckfat',
#        'highroller lobster', 'eventide oyster company',
#        'central provisions', 'scales', 'wayside tavern', 'bird and co',
#        "luke's lobster portland pier", 'knotted apron', 'fore street',
#        'honey paw', 'twelve', 'via vecchia', 'blyth and burrows',
#        'salt yard cafe and bar', 'paper tiger', 'boda',
#        'bread and friends', 'independent ice', 'evo kitchen + bar',
#        'maine oyster company', 'sur lie', 'terlingua', 'leeward',
#        'izakaya minato', 'solo italiano', 'crispy gai', 'quanto basta',
#        'empire chinese kitchen', 'union restaurant', 'isa bistro', 'papi',
#        'chaval', 'north point', 'butcher burger', 'n to tail',
#        "dimillo's on the water", 'bramhall', 'smoked portland',
#        'great lost bear', 'hot suppa', 'miyake', 'jing yan',
#        'keg and kraken', 'quiero cafe', 'mash tun', 'thirsty pig',
# ...

# %%
open_table_res
# Out:
#     Unnamed: 0              restaurant_name      city state  \
# 0            0               street and co.  Portland    ME
# 1            1                       scales  Portland    ME
# 2            2                  bird and co  Portland    ME
# 3            3                  fore street  Portland    ME
# 4            4            bread and friends  Portland    ME
# 5            5         maine oyster company  Portland    ME
# 6            6                solo italiano  Portland    ME
# 7            7                   isa bistro  Portland    ME
# 8            8                    n to tail  Portland    ME
# 9            9                     jing yan  Portland    ME
# 10          11                armory lounge  Portland    ME
# 11          12                   rigby yard  Portland    ME
# 12          13                   east ender  Portland    ME
# 13          14                      regards  Portland    ME
# 14          15                   grill room  Portland    ME
# ...

# %%
open_table_review.head()
# Out:
#    Unnamed: 0 restaurant_name    datelike reviewer_name           city  \
# 0           0  street and co.  2024-07-20         lisas  New York City
# 1           1  street and co.  2024-07-19          JazB  New York City
# 2           2  street and co.  2024-07-18        Mel707       Portland
# 3           3  street and co.  2024-07-18         mmsfo  San Francisco
# 4           4  street and co.  2024-07-16     sharlott2         London
#
#    overall  food  service  ambience  \
# 0        5     5        5         5
# 1        5     5        5         5
# 2        3     3        5         5
# 3        4     5        5         2
# 4        5     5        5         5
#
#                                          review_text     origins
# 0  Amazing food. Great vibe. Good drinks. Perfect...  open_table
# 1  We went with our 21 month old. The staff was b...  open_table
# 2  After not having been there in over 20 years w...  open_table
# ...

# %%
open_table_review[open_table_review["reviewer_name"].isna()]
# Out:
#       Unnamed: 0 restaurant_name    datelike reviewer_name         city  \
# 3118        3508         regards  2023-03-16           NaN  Mexico City
#
#       overall  food  service  ambience  \
# 3118        2     3        1         3
#
#                                             review_text     origins
# 3118  We had one of the worst experiences in a Portl...  open_table

# %%
yelp_review[yelp_review["reviewer_name"].isna()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, restaurant_name, datelike, reviewer_name, city, state, country, rating, review_text, origins]
# Index: []

# %%
yelp_review.shape
# Out:
# (33469, 10)

# %%
open_table_review.shape
# Out:
# (6980, 11)
